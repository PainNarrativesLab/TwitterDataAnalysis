# %% [markdown]
# This includes tools for examining which words occur together anywhere in a tweet or user profile without regard to their relative positions.
#
# Tools for investigating relative positions are in the Word Searching notebook

# %%
# %cd twitteranalysis
import sqlite3
import environment
import pandas as pd
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

#Set default to svg

#let pandas dataframe listings go long
pd.options.display.max_rows = 999
# Out:
# (bookmark:twitteranalysis) -> /Users/adam/Dropbox/PainNarrativesLab/TwitterDataAnalysis
# /Users/adam/Dropbox/PainNarrativesLab/TwitterDataAnalysis

# %%
CO_OCCURRING_TERMS_FOLDER = "%s/co-occurring-terms" % environment.LOG_FOLDER_PATH

def make_filepath(word):
    return "%s/words-in-tweets-using-%s.pickle" % (CO_OCCURRING_TERMS_FOLDER, word)

# %% [markdown]
# # Create test data

# %%
TEST_DB = "%s/test-data.db" % environment.LOG_FOLDER_PATH

tweet1 = 'a b c d e f. a b c d.'
tweet2 = 'e f g h. i j k l.'
tweet3 = 'a e. a. i.'

# %%
expect = {'a' : 2,
    'b': 1,
    'c': 1,
    'd': 1.
    'e':2,
    'f': 1,
    'g': 1,
    'h': 1,
    'i': 2,
    'j': 1,
    'k': 1,
    'l': 1}

# %% [markdown]
# ## All words for tweets

# %%
 # query = """
# SELECT a.word, count(a.word)
# FROM word_map a
# WHERE a.tweet_id = (
# SELECT tweet_id
# FROM word_map b
# WHERE b.word = ? 
# )
# GROUP BY a.word

# """

# %%
def get_all_words_in_tweet(tweetId, db):
    """
    Returns all the words used in the tweet
    
    Example:
        words = get_all_words_in_tweet(331546674315014144, db=environment.TWEET_DB_NO_STOP)
        words = [x[2] for x in words]
    Result:
        words = ['thought', 'crying', 
        'like', 'crazy',
        'im', 'tired', 
        'pain','inevitability', 
        'rely', 'life',
        'spoonie']
    """
    conn = sqlite3.connect(db)
    query = "SELECT * FROM word_map WHERE tweet_id = ?"
    param = (tweetId, )
    with conn:
        r = conn.execute(query, param)
        return r.fetchall()

# %%
def get_cooccuring_word_frequencies(word, save_path=None, db=environment.TWEET_DB_NO_STOP):
    """Returns a dataframe of the frequencies with which words
    appear in tweets containing the provided word
    
    todo Must be verified that this is correct!!!!!
  
    """
    
    query2 ="""
    SELECT a.word, count(distinct a.tweet_id)
    FROM word_map a
    JOIN word_map b
    ON a.tweet_id = b.tweet_id
    WHERE b.word = ?
    GROUP BY a.word
    """

    conn = sqlite3.connect(db)
    param = (word, )
    with conn:
        r = conn.execute(query2, param)
        result = r.fetchall()
    result = [{'word' : x[0], 'freq' : x[1]} for x in result]
    result = pd.DataFrame(result)
    
    if save_path != None:
        result.to_pickle(save_path)
    
    return result

# %%
# %%time
term = 'toothache'

f = get_cooccuring_word_frequencies(term, make_filepath(term))
print(len(f))
# Out:
# 5973
# CPU times: user 130 ms, sys: 69.9 ms, total: 200 ms
# Wall time: 200 ms

# %%
d = pd.read_pickle(make_filepath(term))
d.set_index('word', inplace=True)
len(d)
# Out:
# 5973

# %%
d.sort_values('freq').head(100)
# Out:
#                                                     freq
# word
# inner                                                  1
# migrainelife                                           1
# migraine\xe2\x80\xa6                                   1
# mighty                                                 1
# mien                                                   1
# microsoft                                              1
# michelle                                               1
# mikeyguitar_                                           1
# michael5sos                                            1
# mg                                                     1
# mf                                                     1
# metronizadole                                          1
# methods                                                1
# method                                                 1
# metal                                                  1
# miami                                                  1
# metafit                                                1
# mikoy                                                  1
# miles                                                  1
# misses                                                 1
# missao                                                 1
# miss_kittybliss                                        1
# mishcastauthor                                         1
# miserable\xe2\x80\xa6                                  1
# mio                                                    1
# mild                                                   1
# minus                                                  1
# mins                                                   1
# minor                                                  1
# mines                                                  1
# mimic                                                  1
# million                                                1
# military                                               1
# mintymuggersoil                                        1
# messes                                                 1
# messerbelousroc                                        1
# messed                                                 1
# medicinenotworking                                     1
# medicinal                                              1
# medication..                                           1
# medicated                                              1
# measures                                               1
# meant                                                  1
# medicines                                              1
# me\xf0\x9f\x98\xad\xf0\x9f\x98\xad\xf0\x9f\x98\...     1
# mcdonalds                                              1
# mcd                                                    1
# mazerage64                                             1
# mayneedmorebooze                                       1
# maynard                                                1
# maycrylikeababy                                        1
# me\n                                                   1
# medlicker                                              1
# meetingtomorrow                                        1
# meets                                                  1
# messages                                               1
# mess                                                   1
# meridians                                              1
# merece                                                 1
# mer                                                    1
# meow                                                   1
# mention                                                1
# menstruation                                           1
# mendontcry\xf0\x9f\x98\xa2\xf0\x9f\x98\xad             1
# mememetey                                              1
# membrane                                               1
# melting                                                1
# melt                                                   1
# mehrtarar                                              1
# mefenamic                                              1
# missmysmile                                            1
# max                                                    1
# mistake                                                1
# mmmm                                                   1
# muerodedolor                                           1
# muelas                                                 1
# mueladeljuicio                                         1
# muclestrains                                           1
# much..                                                 1
# muar                                                   1
# mummydiaries                                           1
# mtvhottest                                             1
# mrs                                                    1
# mrkauffman1951j                                        1
# mri                                                    1
# mr_kanggun                                             1
# mr.c                                                   1
# moving                                                 1
# mssucks                                                1
# movin                                                  1
# murder                                                 1
# muscle/joint                                           1
# mya3010                                                1
# mxim                                                   1
# mw                                                     1
# mutha****a                                             1
# mutha                                                  1
# mute                                                   1
# murderer                                               1
# muststop                                               1

# %%
fig, axes = plt.subplots(figsize=(8,8))
sns.violinplot(d, ax=axes)
fig.tight_layout()

# %%
2e6
# Out:
# 2000000.0

# %%
data = result.copy()
cutoff = 10000

# sift out results by cutoff
data = [x for x in data if x[1]>cutoff]
# make into a list of dictionaries 
data = [{'word' : x[0], 'freq' : x[1]} for x in data]
data = pd.DataFrame(data)
data.describe()
# Out:
#                freq
# count  3.990000e+02
# mean   3.805643e+04
# std    1.919837e+05
# min    1.002800e+04
# 25%    1.278150e+04
# 50%    1.705800e+04
# 75%    2.887500e+04
# max    3.710715e+06

# %%
# top words which occur somewhere in a tweet where the word
# 'pain' occurs.
data.sort_values('freq').tail(100)
# Out:
#         freq                                  word
# 153    28961                                  home
# 385    29146                           wisdomteeth
# 209    29250                               medical
# 371    29459                                   use
# 188    29472                                  live
# 183    29476                                   let
# 268    29567                                 power
# 146    29602                               healing
# 322    30080                                  stop
# 378    30152                                  want
# 13     30219                                  anal
# 165    30221                                 joint
# 74     30231                            depression
# 164    30427                           inspiration
# 89     30630                                   end
# 365    30755                                  turn
# 232    30922                               natural
# 196    31616                                 lower
# 121    31670                                  gain
# 250    31750                                  ouch
# 258    32464                              patients
# 374    32604                                 video
# 299    32747                                   see
# 43     33303                                    ca
# 200    33321                                  make
# 328    33434                                 study
# 7      33564  \xed\x97\x88\xec\x98\x81\xec\x83\x9d
# 309    34021                                 sleep
# 313    34023                             sometimes
# 291    34507                                 right
# 170    34648                                  knee
# 286    35064                               relieve
# 367    35798                                     u
# 35     36643                                  body
# 301    36738                                   sex
# 131    37014                                  good
# 144    37394                              headache
# 233    37463                                  neck
# 331    37846                             suffering
# 349    38093                                  time
# 208    38318                                   may
# 49     39801                                   cbd
# 73     40442                                    de
# 109    41357                                 fibro
# 306    43763                                  sign
# 373    43809                                   via
# 132    44791                                   got
# 65     44894                              creative
# 297    44918                               sbs_mtv
# 337    45550                                  take
# 25     45572                              backpain
# 66     45923                                  crps
# 361    46288                             treatment
# 246    46930                                   one
# 259    47079                                people
# 117    47767                                  free
# 370    47937                                    us
# 234    48954                                  need
# 225    48997                                  much
# 206    50133                             marijuana
# 204    50252                            management
# 329    50673                               success
# 171    51992                                  know
# 135    52527                                    gt
# 157    52695                                  hurt
# 148    53119                               healthy
# 1      53431                                    'm
# 353    54456                                 today
# 214    55218                              migraine
# 71     55446                                   day
# 42     56186                              business
# 104    56603                                  feel
# 118    58325                           freewebinar
# 283    59647                               release
# 317    61369                               spoonie
# 127    63544                                    go
# 185    65355                                  like
# 45     65833                              cannabis
# 326    67706                                stress
# 238    68149                                   new
# 82     72491                            doubles301
# 351    84567                                  tips
# 8      86348                                    ``
# 123    87357                                   get
# 154    90027                                  hope
# 147    90236                                health
# 110    92021                          fibromyalgia
# 150   100826                                  help
# 194   112837                                  love
# 18    122875                             arthritis
# 230   123468                                   n't
# 184   124635                                  life
# 54    164494                               chronic
# 284   179047                                relief
# 56    187032                           chronicpain
# 24    217707                                  back
# 12    222729                                   amp
# 6     239075                                   ...
# 293   934798                                    rt
# 251  3710715                                  pain

# %%
x = data.sort_values('word')[7:16]
[y[1] for y in x.values]
